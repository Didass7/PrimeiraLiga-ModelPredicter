# %%
import pandas as pd
import glob

# Encontrar todos os ficheiros CSV que começam com "goalkeeping", "miscellaneous", "overall", etc.
# Esta é uma forma flexível de adicionar mais ficheiros no futuro.
file_paths = glob.glob('*.csv')

# Lista para armazenar os DataFrames individuais
lista_de_dataframes = []

# Carregar cada ficheiro, definir 'Equipa' como índice e adicionar à lista
for path in file_paths:
    df = pd.read_csv(path)
    if 'Equipa' in df.columns:
        df = df.set_index('Equipa')
        lista_de_dataframes.append(df)

# Concatenar todos os DataFrames da lista ao longo do eixo das colunas (axis=1)
# Isto irá juntar os dataframes lado a lado, alinhados pelo índice ('Equipa')
dataset_completo = pd.concat(lista_de_dataframes, axis=1)

# Remover colunas duplicadas, mantendo a primeira ocorrência
dataset_completo = dataset_completo.loc[:, ~dataset_completo.columns.duplicated()]

# Opcional: Resetar o índice se quiser que 'Equipa' volte a ser uma coluna normal
dataset_completo = dataset_completo.reset_index()

# Opcional: Guardar o dataset final num novo ficheiro CSV
dataset_completo.to_csv('dataset_completo_2024-2025.csv', index=False)

# Mostrar as primeiras linhas e as informações do dataset final para verificação
print("Pré-visualização do Dataset Combinado:")
print(dataset_completo.head())
print("\nInformações do Dataset Combinado:")
dataset_completo.info()
# Out:
# Pré-visualização do Dataset Combinado:
#         Equipa  Desarmes  Intercecoes  Bloqueamentos  Desarmes+Intercecoes  \
# 0       Arouca       552          297            376                   849
# 1  AVS Futebol       565          303            390                   868
# 2      Benfica       625          311            316                   936
# 3     Boavista       565          313            336                   878
# 4        Braga       571          280            333                   851
#
#    Alivios  GolosSofridos  JogosSemSofrerGolos  %DeJogosSemSofrerGolos  \
# 0      852             49                    8                    23.5
# 1      929             60                    8                    23.5
# 2      493             28                   15                    44.1
# 3      843             59                    7                    20.6
# 4      795             30                   15                    44.1
#
#    %DeDefesas  ...  RematesÀBaliza  %DeRematesÀBaliza  \
# 0        71.4  ...             119               30.5
# 1        67.4  ...              87               25.5
# 2        75.5  ...             213               38.1
# 3        69.4  ...             102               29.6
# 4        78.0  ...             155               33.8
#
#    GolosEsperadosSemPenáltis  Assistências  Golos+Assistências  \
# 0                       33.5            18                  52
# 1                       27.7            17                  42
# 2                       69.7            58                 139
# 3                       26.9             8                  31
# 4                       46.5            40                  94
#
#    ConduçõesProgressivas  SaldoDeGolos+/-  SaldoDeGolos+/-Por90minutos  \
# 0                    418              -14                        -0.41
# 1                    388              -35                        -1.03
# 2                    684               56                         1.65
# 3                    264              -35                        -1.03
# 4                    602               25                         0.74
#
#    SaldoDeGolosEsperados+/-  SaldoDeGolosEsperados+/-Por90minutos
# 0                      -6.0                                 -0.18
# 1                     -23.3                                 -0.68
# 2                      49.5                                  1.46
# 3                     -24.0                                 -0.71
# 4                      17.1                                  0.50
#
# [5 rows x 55 columns]
#
# Informações do Dataset Combinado:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 55 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Equipa                                18 non-null     object
#  1   Desarmes                              18 non-null     int64
#  2   Intercecoes                           18 non-null     int64
#  3   Bloqueamentos                         18 non-null     int64
#  4   Desarmes+Intercecoes                  18 non-null     int64
#  5   Alivios                               18 non-null     int64
#  6   GolosSofridos                         18 non-null     int64
#  7   JogosSemSofrerGolos                   18 non-null     int64
#  8   %DeJogosSemSofrerGolos                18 non-null     float64
#  9   %DeDefesas                            18 non-null     float64
#  10  RematesÀBalizaSofridos                18 non-null     int64
#  11  GolosEsperadosAposRemate              18 non-null     float64
#  12  GolosEsperadosAposRemate+/-           18 non-null     float64
#  13  AcoesForaDaGrandeArea                 18 non-null     int64
#  14  AcoesQueCriamRemates                  18 non-null     int64
#  15  AcoesQueCriamRematesPor90minutos      18 non-null     float64
#  16  AcoesQueCriamGolos                    18 non-null     int64
#  17  AcoesQueCriamGolosPor90minutos        18 non-null     float64
#  18  %DeDuelosAereosGanhos                 18 non-null     float64
#  19  JogosDisputados                       18 non-null     int64
#  20  Vitórias                              18 non-null     int64
#  21  Empates                               18 non-null     int64
#  22  Derrotas                              18 non-null     int64
#  23  GolosMarcados                         18 non-null     int64
#  24  DiferençaDeGolos                      18 non-null     int64
#  25  Pontos                                18 non-null     int64
#  26  GolosEsperados                        18 non-null     float64
#  27  GolosEsperadosSofridos                18 non-null     float64
#  28  DiferençaDeGolosEsperados             18 non-null     float64
#  29  %DePassesCompletos                    18 non-null     float64
#  30  DistanciaTotalPercorrida              18 non-null     int64
#  31  DistanciaProgressivaPercorrida        18 non-null     int64
#  32  Assistencias                          18 non-null     int64
#  33  GolosEsperadosAssistidos              18 non-null     float64
#  34  PassesChave                           18 non-null     int64
#  35  PassesProgressivos                    18 non-null     int64
#  36  TentativasDePasse                     18 non-null     int64
#  37  BolasEmProfundidade                   18 non-null     int64
#  38  InversoesDeJogo                       18 non-null     int64
#  39  PosseDeBola                           18 non-null     float64
#  40  ToquesNaBola                          18 non-null     int64
#  41  ConducoesProgressivas                 18 non-null     int64
#  42  RececoesProgressivas                  18 non-null     int64
#  43  Golos                                 18 non-null     int64
#  44  Remates                               18 non-null     int64
#  45  RematesÀBaliza                        18 non-null     int64
#  46  %DeRematesÀBaliza                     18 non-null     float64
#  47  GolosEsperadosSemPenáltis             18 non-null     float64
#  48  Assistências                          18 non-null     int64
#  49  Golos+Assistências                    18 non-null     int64
#  50  ConduçõesProgressivas                 18 non-null     int64
#  51  SaldoDeGolos+/-                       18 non-null     int64
#  52  SaldoDeGolos+/-Por90minutos           18 non-null     float64
#  53  SaldoDeGolosEsperados+/-              18 non-null     float64
#  54  SaldoDeGolosEsperados+/-Por90minutos  18 non-null     float64
# dtypes: float64(18), int64(36), object(1)
# memory usage: 7.9+ KB

# %%
import pandas as pd

# Carregar o dataset previamente combinado
try:
    df = pd.read_csv('dataset_completo_2024-2025.csv')
except FileNotFoundError:
    print("O ficheiro 'dataset_completo_2024-2025.csv' não foi encontrado.")
    print("Por favor, execute primeiro o script anterior para gerar este ficheiro.")
    exit()


# Lista de colunas a serem removidas
# Escolhemos manter a versão mais descritiva ou corretamente acentuada
colunas_para_remover = [
    'Golos',                 # Redundante com 'GolosMarcados'
    'Assistencias',          # Redundante com 'Assistências'
    'ConducoesProgressivas', # Redundante com 'ConduçõesProgressivas'
    'Golos+Assistências'     # Coluna derivada (soma de outras duas)
]

# Verificar quais das colunas a remover realmente existem no DataFrame antes de tentar removê-las
colunas_existentes_para_remover = [col for col in colunas_para_remover if col in df.columns]

if colunas_existentes_para_remover:
    # Remover as colunas identificadas
    df_limpo = df.drop(columns=colunas_existentes_para_remover)
    print(f"Colunas removidas: {colunas_existentes_para_remover}")
else:
    df_limpo = df
    print("Nenhuma coluna redundante para remover foi encontrada.")


# Opcional: Renomear colunas para consistência, se desejado (exemplo)
# df_limpo = df_limpo.rename(columns={'Assistências': 'TotalDeAssistencias'})


# Guardar o novo dataset final e limpo
df_limpo.to_csv('dataset_final_limpo_2024-2025.csv', index=False)


# Mostrar as informações do dataset final para confirmar que as colunas foram removidas
print("\nInformações do Dataset Final Limpo:")
df_limpo.info()

print("\nPré-visualização do Dataset Final Limpo:")
print(df_limpo.head())
# Out:
# Colunas removidas: ['Golos', 'Assistencias', 'ConducoesProgressivas', 'Golos+Assistências']
#
# Informações do Dataset Final Limpo:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 51 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Equipa                                18 non-null     object
#  1   Desarmes                              18 non-null     int64
#  2   Intercecoes                           18 non-null     int64
#  3   Bloqueamentos                         18 non-null     int64
#  4   Desarmes+Intercecoes                  18 non-null     int64
#  5   Alivios                               18 non-null     int64
#  6   GolosSofridos                         18 non-null     int64
#  7   JogosSemSofrerGolos                   18 non-null     int64
#  8   %DeJogosSemSofrerGolos                18 non-null     float64
#  9   %DeDefesas                            18 non-null     float64
#  10  RematesÀBalizaSofridos                18 non-null     int64
#  11  GolosEsperadosAposRemate              18 non-null     float64
#  12  GolosEsperadosAposRemate+/-           18 non-null     float64
#  13  AcoesForaDaGrandeArea                 18 non-null     int64
#  14  AcoesQueCriamRemates                  18 non-null     int64
#  15  AcoesQueCriamRematesPor90minutos      18 non-null     float64
#  16  AcoesQueCriamGolos                    18 non-null     int64
#  17  AcoesQueCriamGolosPor90minutos        18 non-null     float64
#  18  %DeDuelosAereosGanhos                 18 non-null     float64
#  19  JogosDisputados                       18 non-null     int64
#  20  Vitórias                              18 non-null     int64
#  21  Empates                               18 non-null     int64
#  22  Derrotas                              18 non-null     int64
#  23  GolosMarcados                         18 non-null     int64
#  24  DiferençaDeGolos                      18 non-null     int64
#  25  Pontos                                18 non-null     int64
#  26  GolosEsperados                        18 non-null     float64
#  27  GolosEsperadosSofridos                18 non-null     float64
#  28  DiferençaDeGolosEsperados             18 non-null     float64
#  29  %DePassesCompletos                    18 non-null     float64
#  30  DistanciaTotalPercorrida              18 non-null     int64
#  31  DistanciaProgressivaPercorrida        18 non-null     int64
#  32  GolosEsperadosAssistidos              18 non-null     float64
#  33  PassesChave                           18 non-null     int64
#  34  PassesProgressivos                    18 non-null     int64
#  35  TentativasDePasse                     18 non-null     int64
#  36  BolasEmProfundidade                   18 non-null     int64
#  37  InversoesDeJogo                       18 non-null     int64
#  38  PosseDeBola                           18 non-null     float64
#  39  ToquesNaBola                          18 non-null     int64
#  40  RececoesProgressivas                  18 non-null     int64
#  41  Remates                               18 non-null     int64
#  42  RematesÀBaliza                        18 non-null     int64
#  43  %DeRematesÀBaliza                     18 non-null     float64
#  44  GolosEsperadosSemPenáltis             18 non-null     float64
#  45  Assistências                          18 non-null     int64
#  46  ConduçõesProgressivas                 18 non-null     int64
#  47  SaldoDeGolos+/-                       18 non-null     int64
#  48  SaldoDeGolos+/-Por90minutos           18 non-null     float64
#  49  SaldoDeGolosEsperados+/-              18 non-null     float64
#  50  SaldoDeGolosEsperados+/-Por90minutos  18 non-null     float64
# dtypes: float64(18), int64(32), object(1)
# memory usage: 7.3+ KB
#
# Pré-visualização do Dataset Final Limpo:
#         Equipa  Desarmes  Intercecoes  Bloqueamentos  Desarmes+Intercecoes  \
# 0       Arouca       552          297            376                   849
# 1  AVS Futebol       565          303            390                   868
# 2      Benfica       625          311            316                   936
# 3     Boavista       565          313            336                   878
# 4        Braga       571          280            333                   851
#
#    Alivios  GolosSofridos  JogosSemSofrerGolos  %DeJogosSemSofrerGolos  \
# 0      852             49                    8                    23.5
# 1      929             60                    8                    23.5
# 2      493             28                   15                    44.1
# 3      843             59                    7                    20.6
# 4      795             30                   15                    44.1
#
#    %DeDefesas  ...  Remates  RematesÀBaliza  %DeRematesÀBaliza  \
# 0        71.4  ...      390             119               30.5
# 1        67.4  ...      341              87               25.5
# 2        75.5  ...      559             213               38.1
# 3        69.4  ...      345             102               29.6
# 4        78.0  ...      459             155               33.8
#
#    GolosEsperadosSemPenáltis  Assistências  ConduçõesProgressivas  \
# 0                       33.5            18                    418
# 1                       27.7            17                    388
# 2                       69.7            58                    684
# 3                       26.9             8                    264
# 4                       46.5            40                    602
#
#    SaldoDeGolos+/-  SaldoDeGolos+/-Por90minutos  SaldoDeGolosEsperados+/-  \
# 0              -14                        -0.41                      -6.0
# 1              -35                        -1.03                     -23.3
# 2               56                         1.65                      49.5
# 3              -35                        -1.03                     -24.0
# 4               25                         0.74                      17.1
#
#    SaldoDeGolosEsperados+/-Por90minutos
# 0                                 -0.18
# 1                                 -0.68
# 2                                  1.46
# 3                                 -0.71
# 4                                  0.50
#
# [5 rows x 51 columns]

# %%
df
# Out:
#             Equipa  Desarmes  Intercecoes  Bloqueamentos  \
# 0           Arouca       552          297            376
# 1      AVS Futebol       565          303            390
# 2          Benfica       625          311            316
# 3         Boavista       565          313            336
# 4            Braga       571          280            333
# 5         Casa Pia       497          297            364
# 6          Estoril       530          324            331
# 7          Estrela       613          306            388
# 8        Famalicão       560          296            323
# 9          Farense       589          327            390
# 10  Gil Vicente FC       539          310            357
# 11      Moreirense       547          283            336
# 12        Nacional       555          287            387
# 13           Porto       472          253            300
# 14         Rio Ave       597          312            359
# 15     Santa Clara       559          288            335
# 16     Sporting CP       545          252            318
# 17         Vitória       528          267            319
#
#     Desarmes+Intercecoes  Alivios  GolosSofridos  JogosSemSofrerGolos  \
# 0                    849      852             49                    8
# 1                    868      929             60                    8
# 2                    936      493             28                   15
# 3                    878      843             59                    7
# 4                    851      795             30                   15
# 5                    794      907             44                    7
# 6                    854      901             53                    7
# 7                    919      969             50                    7
# 8                    856      800             39                   13
# 9                    916      992             46                    7
# 10                   849      868             47                    7
# 11                   830     1015             50                    7
# 12                   842      878             50                    8
# 13                   725      521             30                   16
# 14                   909      959             55                    5
# 15                   847      966             32                   11
# 16                   797      556             27                   15
# 17                   795      764             37                   13
#
#     %DeJogosSemSofrerGolos  %DeDefesas  ...  RematesÀBaliza  \
# 0                     23.5        71.4  ...             119
# 1                     23.5        67.4  ...              87
# 2                     44.1        75.5  ...             213
# 3                     20.6        69.4  ...             102
# 4                     44.1        78.0  ...             155
# 5                     20.6        77.3  ...              98
# 6                     20.6        69.5  ...             112
# 7                     20.6        69.8  ...              89
# 8                     38.2        74.6  ...             124
# 9                     20.6        72.8  ...             114
# 10                    20.6        68.0  ...              95
# 11                    20.6        67.2  ...             125
# 12                    23.5        73.7  ...             129
# 13                    47.1        74.2  ...             170
# 14                    14.7        69.2  ...             123
# 15                    32.4        75.4  ...             124
# 16                    44.1        68.5  ...             210
# 17                    38.2        68.0  ...             141
#
#     %DeRematesÀBaliza  GolosEsperadosSemPenáltis  Assistências  \
# 0                30.5                       33.5            18
# 1                25.5                       27.7            17
# 2                38.1                       69.7            58
# 3                29.6                       26.9             8
# 4                33.8                       46.5            40
# 5                31.2                       30.2            26
# 6                34.1                       34.9            28
# 7                27.2                       26.3            16
# 8                32.5                       34.4            29
# 9                29.7                       28.2            18
# 10               29.2                       30.7            20
# 11               36.5                       29.5            28
# 12               28.6                       33.9            21
# 13               35.9                       47.8            44
# 14               33.2                       35.8            20
# 15               32.8                       39.4            25
# 16               34.4                       62.6            56
# 17               31.8                       42.2            27
#
#     Golos+Assistências  ConduçõesProgressivas  SaldoDeGolos+/-  \
# 0                   52                    418              -14
# 1                   42                    388              -35
# 2                  139                    684               56
# 3                   31                    264              -35
# 4                   94                    602               25
# 5                   62                    397               -5
# 6                   75                    403               -5
# 7                   39                    354              -26
# 8                   72                    437                5
# 9                   43                    354              -21
# 10                  53                    451              -13
# 11                  69                    416               -8
# 12                  52                    466              -18
# 13                 109                    578               35
# 14                  59                    493              -16
# 15                  60                    401                4
# 16                 142                    797               61
# 17                  70                    504               10
#
#     SaldoDeGolos+/-Por90minutos  SaldoDeGolosEsperados+/-  \
# 0                         -0.41                      -6.0
# 1                         -1.03                     -23.3
# 2                          1.65                      49.5
# 3                         -1.03                     -24.0
# 4                          0.74                      17.1
# 5                         -0.15                     -11.8
# 6                         -0.15                     -16.9
# 7                         -0.76                     -16.3
# 8                          0.15                      -3.9
# 9                         -0.62                     -20.9
# 10                        -0.38                      -8.3
# 11                        -0.24                      -6.1
# 12                        -0.53                     -10.4
# 13                         1.03                      26.1
# 14                        -0.47                     -15.5
# 15                         0.12                       9.7
# 16                         1.79                      48.8
# 17                         0.29                      12.2
#
#     SaldoDeGolosEsperados+/-Por90minutos
# 0                                  -0.18
# 1                                  -0.68
# 2                                   1.46
# 3                                  -0.71
# 4                                   0.50
# 5                                  -0.35
# 6                                  -0.50
# 7                                  -0.48
# 8                                  -0.12
# 9                                  -0.61
# 10                                 -0.24
# 11                                 -0.18
# 12                                 -0.31
# 13                                  0.77
# 14                                 -0.46
# 15                                  0.28
# 16                                  1.43
# 17                                  0.36
#
# [18 rows x 55 columns]
