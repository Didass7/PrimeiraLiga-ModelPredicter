# %%
import pandas as pd

# %%
df= pd.read_csv("dataset_completo_final.csv")

# %%
df.head()
# Out:
#         Equipa  JogosDisputados  Vitórias  Empates  Derrotas  GolosMarcados  \
# 0  Sporting CP               34        25        7         2             88
# 1      Benfica               34        25        5         4             84
# 2        Porto               34        22        5         7             65
# 3        Braga               34        19        9         6             55
# 4  Santa Clara               34        17        6        11             36
#
#    DiferençaDeGolos  Pontos  GolosEsperadosSofridos  \
# 0                61      82                    23.4
# 1                56      80                    29.2
# 2                35      71                    30.4
# 3                25      66                    34.2
# 4                 4      57                    32.9
#
#    DiferençaDeGolosEsperados  ...  SaldoDeGolos+/-Por90minutos  \
# 0                       48.8  ...                         1.79
# 1                       49.5  ...                         1.65
# ...

# %%
df.describe()
# Out:
#        JogosDisputados    Vitórias     Empates    Derrotas  GolosMarcados  \
# count       362.000000  362.000000  362.000000  362.000000     362.000000
# mean         32.585635   12.168508    8.248619   12.168508      40.925414
# std           1.914983    6.067196    2.904588    5.212047      15.492558
# min          30.000000    2.000000    1.000000    0.000000      19.000000
# 25%          30.000000    8.000000    6.000000    9.000000      30.000000
# 50%          34.000000   10.000000    8.000000   13.000000      37.000000
# 75%          34.000000   15.000000   10.000000   16.000000      46.000000
# max          34.000000   29.000000   19.000000   27.000000     103.000000
#
#        DiferençaDeGolos      Pontos  GolosEsperadosSofridos  \
# count        362.000000  362.000000              362.000000
# mean           0.000000   44.745856               15.577901
# std           24.192098   16.927303               22.111357
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 56 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Equipa                                362 non-null    object
#  1   JogosDisputados                       362 non-null    int64
#  2   Vitórias                              362 non-null    int64
#  3   Empates                               362 non-null    int64
#  4   Derrotas                              362 non-null    int64
#  5   GolosMarcados                         362 non-null    int64
#  6   DiferençaDeGolos                      362 non-null    int64
#  7   Pontos                                362 non-null    int64
#  8   GolosEsperadosSofridos                362 non-null    float64
#  9   DiferençaDeGolosEsperados             362 non-null    float64
#  10  Assistências                          362 non-null    int64
# ...

# %%
df['Golos'].sum()
# Out:
# np.float64(5395.0)

# %%
df[['Golos', 'Equipa', 'Epoca']]
# Out:
#      Golos           Equipa      Epoca
# 0     86.0      Sporting CP  2024-2025
# 1     81.0          Benfica  2024-2025
# 2     65.0            Porto  2024-2025
# 3     54.0            Braga  2024-2025
# 4     35.0      Santa Clara  2024-2025
# ..     ...              ...        ...
# 357    0.0        Académica  2004-2005
# 358    0.0  União de Leiria  2004-2005
# 359    0.0       Moreirense  2004-2005
# 360    0.0          Estoril  2004-2005
# 361    0.0        Beira-Mar  2004-2005
#
# [362 rows x 3 columns]
