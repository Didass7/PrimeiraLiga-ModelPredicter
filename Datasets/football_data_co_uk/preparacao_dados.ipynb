# %%
import pandas as pd
import glob
import os

# Usar caminhos absolutos para não haver erro
path_fbref = r"d:/Diogo/Ambiente de Trabalho/PROJETO/Datasets/FBRef/dataset_completo_final.csv"
path_fd = r"d:/Diogo/Ambiente de Trabalho/PROJETO/Datasets/football_data_co_uk/"

# Carregar FBRef
try:
    df_fbref = pd.read_csv(path_fbref)
    print("FBRef carregado com sucesso!")
except FileNotFoundError:
    print(f"Erro: Não encontrei o ficheiro em {path_fbref}")

# Carregar jogos todos
files = glob.glob(os.path.join(path_fd, "P1_*.csv"))
dfs = []
for f in files:
    dfs.append(pd.read_csv(f))

if dfs:
    df_matches = pd.concat(dfs, ignore_index=True)
    df_matches['Date'] = pd.to_datetime(df_matches['Date'], dayfirst=True, errors='coerce')
    df_matches = df_matches.sort_values('Date')
    print("Jogos carregados com sucesso!")
else:
    print("Aviso: Não encontrei ficheiros CSV na pasta football_data_co_uk")

# Ver diferenças nos nomes
if 'df_fbref' in locals() and 'df_matches' in locals():
    print("\nFBRef Equipas:", sorted(df_fbref['Equipa'].unique().astype(str)))
    print("\nFootball Data Equipas:", sorted(df_matches['HomeTeam'].unique().astype(str)))
# Out:
# FBRef carregado com sucesso!
# Jogos carregados com sucesso!
#
# FBRef Equipas: [np.str_('AVS Futebol'), np.str_('Académica'), np.str_('Arouca'), np.str_('Aves'), np.str_('B-SAD'), np.str_('Beira-Mar'), np.str_('Belenenses'), np.str_('Benfica'), np.str_('Boavista'), np.str_('Braga'), np.str_('Casa Pia'), np.str_('Chaves'), np.str_('Estoril'), np.str_('Estrela'), np.str_('Famalicão'), np.str_('Farense'), np.str_('Feirense'), np.str_('Gil Vicente'), np.str_('Gil Vicente FC'), np.str_('Leixões'), np.str_('Marítimo'), np.str_('Moreirense'), np.str_('Nacional'), np.str_('Naval'), np.str_('Olhanense'), np.str_('Paços de Ferreira'), np.str_('Penafiel'), np.str_('Portimonense'), np.str_('Porto'), np.str_('Rio Ave'), np.str_('Santa Clara'), np.str_('Sporting CP'), np.str_('Tondela'), np.str_('Trofense'), np.str_('União'), np.str_('União de Leiria'), np.str_('Vitória'), np.str_('Vitória Setúbal'), np.str_('Vizela')]
#
# Football Data Equipas: [np.str_('AVS'), np.str_('Academica'), np.str_('Alverca'), np.str_('Arouca'), np.str_('Aves'), np.str_('Beira Mar'), np.str_('Belenenses'), np.str_('Benfica'), np.str_('Boavista'), np.str_('Casa Pia'), np.str_('Chaves'), np.str_('Estoril'), np.str_('Estrela'), np.str_('Famalicao'), np.str_('Farense'), np.str_('Feirense'), np.str_('Feirense '), np.str_('Gil Vicente'), np.str_('Guimaraes'), np.str_('Leiria'), np.str_('Maritimo'), np.str_('Moreirense'), np.str_('Nacional'), np.str_('Naval'), np.str_('Olhanense'), np.str_('Pacos Ferreira'), np.str_('Penafiel'), np.str_('Portimonense'), np.str_('Porto'), np.str_('Rio Ave'), np.str_('Santa Clara'), np.str_('Setubal'), np.str_('Sp Braga'), np.str_('Sp Lisbon'), np.str_('Tondela'), np.str_('Uniao Madeira'), np.str_('Vizela'), np.str_('nan')]
# C:\Users\diogo\AppData\Local\Temp\ipykernel_16704\3672155031.py:24: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_matches['Date'] = pd.to_datetime(df_matches['Date'], dayfirst=True, errors='coerce')

# %%
# Mapeamento de equipas (Preencher com o que vi nos prints acima)
mapping = {
    # "Nome no Football Data": "Nome no FBRef"
    # Exemplo:
    # "Sp Lisbon": "Sporting CP",
    "AVS Futebol": "AVS",
    "Académica": "Academica",
    "Beira-Mar": "Beira Mar",
    "Famalicão": "Famalicao",
    
}

# Aplicar (descomentar quando o mapping estiver feito)
# df_matches['HomeTeam'] = df_matches['HomeTeam'].replace(mapping)
# df_matches['AwayTeam'] = df_matches['AwayTeam'].replace(mapping)
